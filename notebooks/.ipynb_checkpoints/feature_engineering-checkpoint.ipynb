# %% [markdown]
# # Read Dataset

# %%
import pandas as pd
pd.set_option("display.max_columns", None)

df = pd.read_csv("../datasets/raw/train.csv", index_col="PassengerId")
df.sample(n=3)
# Out:
#              Survived  Pclass                           Name   Sex  Age  \
# PassengerId
# 869                 0       3    van Melkebeke, Mr. Philemon  male  NaN
# 65                  0       1          Stewart, Mr. Albert A  male  NaN
# 177                 0       3  Lefebre, Master. Henry Forbes  male  NaN
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 869              0      0    345777   9.5000   NaN        S
# 65               0      0  PC 17605  27.7208   NaN        C
# 177              3      1      4133  25.4667   NaN        S

# %% [markdown]
# # Transformation

# %% [markdown]
# ## Rename Column

# %%
df.rename(
    columns={
        old: old.lower() for old in df.columns
    },
    inplace=True
)

df.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df_transform = df.copy()

# %% [markdown]
# ## title

# %%
df_transform["title"] = df_transform.name.apply(lambda x: x.split(".")[0].split(",")[1].strip())

def replace_title(df):
    title = df["title"]
    if title in ['Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col', "Sir"]:
        return "Mr"
    elif title in ['the Countess', 'Mme', "Lady", "Dona"]:
        return "Mrs"
    elif title in ['Mlle', 'Ms']:
        return "Miss"
    elif title == "Dr":
        if df["sex"] == "male":
            return "Mr"
        else:
            return "Mrs"
    else:
        return title
    
df_transform["title"] = df_transform.apply(replace_title, axis=1)
df_transform.sample(n=3)
# Out:
#              survived  pclass                name   sex   age  sibsp  parch  \
# PassengerId
# 211                 0       3      Ali, Mr. Ahmed  male  24.0      0      0
# 469                 0       3  Scanlan, Mr. James  male   NaN      0      0
# 740                 0       3  Nankoff, Mr. Minko  male   NaN      0      0
#
#                          ticket    fare cabin embarked title
# PassengerId
# 211          SOTON/O.Q. 3101311  7.0500   NaN        S    Mr
# 469                       36209  7.7250   NaN        Q    Mr
# 740                      349218  7.8958   NaN        S    Mr

# %% [markdown]
# ## deck

# %%
def deck_category(cabin):
    if isinstance(cabin, float):
        return "unknown"
    elif "A" in cabin:
        return "A"
    elif "B" in cabin:
        return "B"
    elif "C" in cabin:
        return "C"
    elif "D" in cabin:
        return "D"
    elif "E" in cabin:
        return "E"
    elif "F" in cabin:
        return "F"
    elif "G" in cabin:
        return "G"
    elif "T" in cabin:
        return "T"
    elif "F" in cabin and "E" in cabin:
        return "FE"
    elif "F" in cabin and "G" in cabin:
        return "FG"
    
df_transform["deck"] = df_transform.cabin.apply(deck_category)
df_transform.sample(n=3)
# Out:
#              survived  pclass                           name   sex   age  \
# PassengerId
# 516                 0       1   Walker, Mr. William Anderson  male  47.0
# 869                 0       3    van Melkebeke, Mr. Philemon  male   NaN
# 177                 0       3  Lefebre, Master. Henry Forbes  male   NaN
#
#              sibsp  parch  ticket     fare cabin embarked   title     deck
# PassengerId
# 516              0      0   36967  34.0208   D46        S      Mr        D
# 869              0      0  345777   9.5000   NaN        S      Mr  unknown
# 177              3      1    4133  25.4667   NaN        S  Master  unknown

# %% [markdown]
# ## fare

# %%
def transform_fare(fare):
    if fare <= 50:
        return 1
    elif 50 < fare <= 150:
        return 2
    else:
        return 3

df_transform["fare_category"] = df_transform.fare.apply(transform_fare)
df_transform.sample(n=3)
# Out:
#              survived  pclass                             name     sex   age  \
# PassengerId
# 377                 1       3  Landergren, Miss. Aurora Adelia  female  22.0
# 220                 0       2               Harris, Mr. Walter    male  30.0
# 625                 0       3      Bowen, Mr. David John "Dai"    male  21.0
#
#              sibsp  parch     ticket   fare cabin embarked title     deck  \
# PassengerId
# 377              0      0     C 7077   7.25   NaN        S  Miss  unknown
# 220              0      0  W/C 14208  10.50   NaN        S    Mr  unknown
# 625              0      0      54636  16.10   NaN        S    Mr  unknown
#
#              fare_category
# PassengerId
# 377                      1
# 220                      1
# 625                      1

# %%
df_transform["no_ticket"] = df_transform.ticket.apply(lambda x: x.split(" ")[0])
df_transform.sample(n=3)
# Out:
#              survived  pclass                             name     sex   age  \
# PassengerId
# 216                 1       1          Newell, Miss. Madeleine  female  31.0
# 725                 1       1    Chambers, Mr. Norman Campbell    male  27.0
# 650                 1       3  Stanley, Miss. Amy Zillah Elsie  female  23.0
#
#              sibsp  parch    ticket     fare cabin embarked title     deck  \
# PassengerId
# 216              1      0     35273  113.275   D36        C  Miss        D
# 725              1      0    113806   53.100    E8        S    Mr        E
# 650              0      0  CA. 2314    7.550   NaN        S  Miss  unknown
#
#              fare_category no_ticket
# PassengerId
# 216                      2     35273
# 725                      2    113806
# 650                      1       CA.

# %% [markdown]
# ## is_alone

# %%
import numpy as np

df_transform["is_alone"] = np.uint8((df_transform.sibsp == 0) & (df_transform.parch == 0))
df_transform.sample(n=3)
# Out:
#              survived  pclass                              name   sex   age  \
# PassengerId
# 386                 0       2         Davies, Mr. Charles Henry  male  18.0
# 573                 1       1  Flynn, Mr. John Irwin ("Irving")  male  36.0
# 833                 0       3                    Saad, Mr. Amin  male   NaN
#
#              sibsp  parch        ticket     fare cabin embarked title  \
# PassengerId
# 386              0      0  S.O.C. 14879  73.5000   NaN        S    Mr
# 573              0      0      PC 17474  26.3875   E25        S    Mr
# 833              0      0          2671   7.2292   NaN        C    Mr
#
#                 deck  fare_category no_ticket  is_alone
# PassengerId
# 386          unknown              2    S.O.C.         1
# 573                E              1        PC         1
# 833          unknown              1      2671         1

# %% [markdown]
# ## family size

# %%
df_transform["family_size"] = df_transform.sibsp + df_transform.parch
df_transform.sample(n=3)
# Out:
#              survived  pclass  \
# PassengerId
# 320                 1       1
# 430                 1       3
# 223                 0       3
#
#                                                           name     sex   age  \
# PassengerId
# 320          Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0
# 430                         Pickard, Mr. Berk (Berk Trembisky)    male  32.0
# 223                                    Green, Mr. George Henry    male  51.0
#
#              sibsp  parch             ticket    fare cabin embarked title  \
# PassengerId
# 320              1      1              16966  134.50   E34        C   Mrs
# 430              0      0  SOTON/O.Q. 392078    8.05   E10        S    Mr
# 223              0      0              21440    8.05   NaN        S    Mr
#
#                 deck  fare_category   no_ticket  is_alone  family_size
# PassengerId
# 320                E              2       16966         0            2
# 430                E              1  SOTON/O.Q.         1            0
# 223          unknown              1       21440         1            0

# %% [markdown]
# ## age * pclass

# %%
df_transform["age*class"] = df_transform["age"] * df_transform["pclass"]
df_transform.sample(n=3)
# Out:
#              survived  pclass                                          name  \
# PassengerId
# 108                 1       3                        Moss, Mr. Albert Johan
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 537                 0       1             Butt, Major. Archibald Willingham
#
#                 sex   age  sibsp  parch  ticket    fare cabin embarked title  \
# PassengerId
# 108            male   NaN      0      0  312991   7.775   NaN        S    Mr
# 4            female  35.0      1      0  113803  53.100  C123        S   Mrs
# 537            male  45.0      0      0  113050  26.550   B38        S    Mr
#
#                 deck  fare_category no_ticket  is_alone  family_size  \
# PassengerId
# 108          unknown              1    312991         1            0
# 4                  C              2    113803         0            1
# 537                B              1    113050         1            0
#
#              age*class
# PassengerId
# 108                NaN
# 4                 35.0
# 537               45.0

# %% [markdown]
# ## fare per person

# %%
df_transform["fare_per_person"] = df_transform["fare"] / (df_transform["family_size"] + 1)
df_transform.sample(n=3)
# Out:
#              survived  pclass                   name   sex   age  sibsp  \
# PassengerId
# 777                 0       3       Tobin, Mr. Roger  male   NaN      0
# 65                  0       1  Stewart, Mr. Albert A  male   NaN      0
# 566                 0       3   Davies, Mr. Alfred J  male  24.0      2
#
#              parch     ticket     fare cabin embarked title     deck  \
# PassengerId
# 777              0     383121   7.7500   F38        Q    Mr        F
# 65               0   PC 17605  27.7208   NaN        C    Mr  unknown
# 566              0  A/4 48871  24.1500   NaN        S    Mr  unknown
#
#              fare_category no_ticket  is_alone  family_size  age*class  \
# PassengerId
# 777                      1    383121         1            0        NaN
# 65                       1        PC         1            0        NaN
# 566                      1       A/4         0            2       72.0
#
#              fare_per_person
# PassengerId
# 777                   7.7500
# 65                   27.7208
# 566                   8.0500

# %%
df_transform.to_csv("../datasets/feature_engineering/train.csv")
